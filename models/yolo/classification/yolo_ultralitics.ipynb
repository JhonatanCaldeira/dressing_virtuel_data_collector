# %%
import pandas as pd

# %%
ds_path='/mnt/e/jhona/Documents/Estudo/AI Microsfot & Simplon.co/Projet_chef_doeuvre/fashion_dataset/'
image_path='/mnt/e/jhona/Documents/Estudo/AI Microsfot & Simplon.co/Projet_chef_doeuvre/fashion_dataset/fashion-dataset/fashion-dataset/images'

# %%
# Remove lines that are not compliance (10 fields)
file_path = ds_path+"/styles.csv"
file_path_traited = ds_path+"/styles_10_categories.csv"

with open(file_path, "r", encoding="utf-8") as file:
    with open(file_path_traited, "w", encoding="utf-8") as new_file:
        for line in file:
            if line.count(",") <= 9:
                new_file.write(line)
            else:
                print(f"Linha tem mais de 9 vírgulas: {line.strip()}")
# Out:
# Linha tem mais de 9 vírgulas: 23100,Men,Accessories,Accessories,Accessory Gift Set,Navy Blue,Fall,2011,Formal,Turtle Men Formal Navy Blue Tie, Cufflink and Pocket Square Combo Set
# Linha tem mais de 9 vírgulas: 23107,Men,Accessories,Accessories,Accessory Gift Set,Purple,Fall,2011,Formal,Turtle Men Formal Purple Tie, Cufflink and Pocket Square Combo Set
# Linha tem mais de 9 vírgulas: 59768,Women,Accessories,Jewellery,Earrings,Gold,Winter,2016,Casual,Estelle Women Gold, Silver and Copper Toned Earrings
# Linha tem mais de 9 vírgulas: 23114,Men,Accessories,Accessories,Accessory Gift Set,Black,Fall,2011,Formal,Turtle Men Formal Black Tie, Cufflink and Pocket Square Combo Set
# Linha tem mais de 9 vírgulas: 23112,Men,Accessories,Accessories,Accessory Gift Set,Red,Fall,2011,Formal,Turtle Men Formal Red Tie, Cufflink and Pocket Square Combo Set
# ...

# %%
ds = pd.read_csv(file_path_traited)

# %%
ds.count()
# Out:
# id                    44423
# gender                44421
# masterCategory        44421
# subCategory           44421
# articleType           44421
# baseColour            44406
# season                44400
# year                  44420
# usage                 44104
# productDisplayName    44414
# dtype: int64

# %%
ds.drop_duplicates(inplace=True)
ds.dropna(inplace=True)

# %%
ds.count()
# Out:
# id                    44074
# gender                44074
# masterCategory        44074
# subCategory           44074
# articleType           44074
# baseColour            44074
# season                44074
# year                  44074
# usage                 44074
# productDisplayName    44074
# dtype: int64

# %%
ds
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44418  17036    Men       Footwear       Shoes           Casual Shoes
# 44419   6461    Men       Footwear  Flip Flops             Flip Flops
# 44420  18842    Men        Apparel     Topwear                Tshirts
# 44421  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44422  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
filter_ds = ds[ds['masterCategory'].isin(['Apparel','Footwear'])]

# %%
filter_ds.drop(['productDisplayName','year','masterCategory','gender','subCategory'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_1391/351607629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_ds.drop(['productDisplayName','year','masterCategory','gender','subCategory'], axis=1, inplace=True)

# %%
filter_ds
# Out:
#           id   articleType baseColour  season   usage
# 0      15970        Shirts  Navy Blue    Fall  Casual
# 1      39386         Jeans       Blue  Summer  Casual
# 3      21379   Track Pants      Black    Fall  Casual
# 4      53759       Tshirts       Grey  Summer  Casual
# 5       1855       Tshirts       Grey  Summer  Casual
# ...      ...           ...        ...     ...     ...
# 44416  12544       Tshirts      Peach    Fall  Casual
# 44417  42234          Tops       Blue  Summer  Casual
# 44418  17036  Casual Shoes      White  Summer  Casual
# 44419   6461    Flip Flops        Red  Summer  Casual
# 44420  18842       Tshirts       Blue    Fall  Casual
#
# [30561 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(filter_ds, train_size=0.8, test_size=0.2, random_state=42, shuffle=True)

# %%
import shutil
import os
ds_train_path = ds_path + "train"
ds_test_path = ds_path + "test"

def copy_image(ds_train_path, dataframe):
    for line in dataframe.to_numpy():
        source_img = image_path+"/"+line[0]+".jpg"

        for cat in line[1:]:
            destination_dir = ds_train_path+"/"+cat
            os.makedirs(destination_dir, exist_ok=True)
            shutil.copy(source_img, destination_dir+"/"+line[0]+".jpg")

copy_image(ds_train_path, X_train)
# copy_image(ds_test_path, X_test)

# %%
X_test
# Out:
#           id   articleType baseColour  season   usage
# 31876  28712        Kurtas       Blue  Summer  Ethnic
# 39024  11732       Tshirts      Black    Fall  Casual
# 7093   44232  Sports Shoes      White  Summer  Sports
# 34689  52915        Sarees      White  Summer  Ethnic
# 43687  13661        Shirts      White    Fall  Formal
# ...      ...           ...        ...     ...     ...
# 38582  13914       Sandals      Black    Fall  Casual
# 35621  20137        Shirts      Green    Fall  Casual
# 28269  31262       Tshirts  Navy Blue  Summer  Casual
# 23433  10809        Shirts      Black    Fall  Casual
# 2790   28005        Briefs       Blue  Summer  Casual
#
# [6113 rows x 5 columns]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data=ds_path, epochs=10, imgsz=640, batch=100)
# Out:
# New https://pypi.org/project/ultralytics/8.3.40 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1050, 4096MiB)
# ...
