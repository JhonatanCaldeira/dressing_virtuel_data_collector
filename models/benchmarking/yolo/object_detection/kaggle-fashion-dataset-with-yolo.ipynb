# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.4/898.4 kB 30.1 MB/s eta 0:00:00
# ...

# %%
/kaggle/input/fashion-dataset-yolo-format/fashion_dataset/fashion_yolo.yml

# %%
from ultralytics import YOLO
import os
# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
fashion_dataset_path = '/kaggle/input/fashion-dataset-yolo-format/fashion_dataset/'
# Train the model
if os.path.exists(fashion_dataset_path+"fashion_yolo.yml"):
    results = model.train(data=fashion_dataset_path+"fashion_yolo.yml", epochs=100)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 189MB/s]
# Ultralytics 8.3.43 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !zip -r kaggle.zip /kaggle/working
# Out:
# updating: kaggle/working/ (stored 0%)
#   adding: kaggle/working/state.db (deflated 49%)
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/val_batch2_labels.jpg (deflated 22%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 17%)
#   adding: kaggle/working/runs/detect/train/R_curve.png (deflated 9%)
#   adding: kaggle/working/runs/detect/train/val_batch1_pred.jpg (deflated 24%)
#   adding: kaggle/working/runs/detect/train/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/weights/best.pt (deflated 10%)
#   adding: kaggle/working/runs/detect/train/weights/last.pt (deflated 10%)
#   adding: kaggle/working/runs/detect/train/val_batch0_pred.jpg (deflated 24%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 17%)
# ...

# %%
# !ls -ltrh
# Out:
# total 45M
# drwxr-xr-x 3 root root 4.0K Dec  6 07:35 runs
# -rw-r--r-- 1 root root  12M Dec  6 07:35 state.db
# -rw-r--r-- 1 root root 5.4M Dec  6 07:35 yolo11n.pt
# -rw-r--r-- 1 root root  28M Dec  6 08:20 kaggle.zip
